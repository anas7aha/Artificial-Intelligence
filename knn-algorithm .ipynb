# %%
#Name : Anas Taha Mushtaha .
#ID : 120220860 .
#collage : Software engineering and AI.
#task : Second Practical assignment .
#university of palestine .

# %%
import warnings
warnings.filterwarnings('ignore')


#1- Import core libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, classification_report

# %%
#  2- Download ready-made Iris data from sklearn
iris = load_iris()
df = pd.DataFrame(iris.data, columns=iris.feature_names)
df['Species'] = pd.Categorical.from_codes(iris.target, iris.target_names)

# %%
# 3- Display some rows of data
print(" Display the first 5 rows of data:")
print(df.head())
# Out:
#  Display the first 5 rows of data:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#   Species
# 0  setosa
# 1  setosa
# 2  setosa
# 3  setosa
# 4  setosa

# %%
#  4- Charts for data analysis
sns.pairplot(df, hue="Species")
plt.suptitle("🔹Graph - Relationships between properties", y=1.02)
plt.show()

df.hist(figsize=(10, 6), edgecolor='black')
plt.suptitle("🔹 Frequency tables for each property", y=1.02)
plt.tight_layout()
plt.show()

# %%
#  5- Preparing data for KNN
X = df.drop("Species", axis=1)
y = df["Species"]

# %%
# Encode text data if any (here the data is pre-encoded)
le = LabelEncoder()
y_encoded = le.fit_transform(y)

# %%
#  6- Data partitioning
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=42)

# %%
# 7- Create a KNN model
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
# 8- Prediction and results
y_pred = knn.predict(X_test)

# %%
print("\n✅ Model accuracy:", accuracy_score(y_test, y_pred))
print("\n✅ Classification Report:\n", classification_report(y_test, y_pred, target_names=iris.target_names))
# Out:
# ✅ Model accuracy: 1.0
#
# ✅ Classification Report:
#                precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        10
#   versicolor       1.00      1.00      1.00         9
#    virginica       1.00      1.00      1.00        11
#
#     accuracy                           1.00        30
#    macro avg       1.00      1.00      1.00        30
# weighted avg       1.00      1.00      1.00        30
